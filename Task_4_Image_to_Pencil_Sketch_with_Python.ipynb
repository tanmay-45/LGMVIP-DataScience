# %% [markdown]
# <a href="https://colab.research.google.com/github/tanmay-45/LGMVIP-DataScience/blob/main/Task_4_Image_to_Pencil_Sketch_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
# importing necessary libraries
import matplotlib.pyplot as plot
from google.colab.patches import cv2_imshow

# %% [markdown]
# Load the original image(RGB image)

# %%
img = cv2.imread("/content/cat-1045782__340.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=497x340 at 0x7F02DB254410>

# %% [markdown]
# Convert the RGB image to greyscale image

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_img)
# Out:
# <PIL.Image.Image image mode=L size=497x340 at 0x7F02DB254110>

# %% [markdown]
# Invert the greyscale image

# %%
invert_img = 225-gray_img
cv2_imshow(invert_img)
# Out:
# <PIL.Image.Image image mode=L size=497x340 at 0x7F02DB251250>

# %% [markdown]
# Smoothen the inverted image using gaussian blur technique

# %%
img_smoothen = cv2.GaussianBlur(invert_img, (21,21), sigmaX = 0, sigmaY = 0)
cv2_imshow(img_smoothen)
# Out:
# <PIL.Image.Image image mode=L size=497x340 at 0x7F02DB251C10>

# %% [markdown]
# Now create a pencil sketch image

# %%
inverted_blurr = 255-img_smoothen
pencil_sketch = cv2.divide(gray_img, invert_img, inverted_blurr, scale = 256.0)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=497x340 at 0x7F02DB241550>

# %%
cv2_imshow(img)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=497x340 at 0x7F02DB247250>
# <PIL.Image.Image image mode=L size=497x340 at 0x7F02DB235A10>
